# %% [markdown]
# <img src="../../images/kalashi.png" align="right" width='193' height='175'></img>
#
# ## Refugees from the realm of dreams...
#
# You are a Kalashi, a compound being made of an incorporeal spirit from the dream world of Kal Dorn fused with a human body and spirit.
#
# TOOD: rest of flavor text for Kalashi intro

# %% [markdown]
# All of the Marked Houses descend from human bloodlines, so Kalashi are not born into these factions and do not have eldritch marks. You earned in a place in one of the Marked Houses by winning the allegiance of its members. Nonetheless, Kalashi are capable of using eldritch speech to produce magical effects, and their unique minds allow them to easily perform some incantations which humans and Kalashi find challenging.
#
# In particular, the fragment of a Kaluus soul within a Kalashi sees our world in a very different way -- to a being native to Kal Dorn, this plane seems strange and alien. This unique perspective allows a Kalashi to use the eldritch tongue to produce images and visualizations which reveal more information about the world around him.
#
# For example, a human of House Larenthil might use his Mark of Storm to create spiraling air currents which lead to rain; a Kalashi, however, can utter a phrase and see the invisible motion of the air miles from the ground:

# %%
## TODO: decide whether this is the right demo and if so wrap it in kalashi_demo()

# %matplotlib notebook
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()
# Out:
# <img src="data:image/png;base64,...">
